# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import os
from tqdm import tqdm

# %%
from fastai.vision import *

# %%
PATH = Path('../data/')

# %% [markdown]
# # Test single image

# %%
tfn_tfms, val_tfms = get_transforms(do_flip=False)
img = open_image(f'{PATH}/valid/cats/cat.10016.jpg').apply_tfms(val_tfms)

# %%
img
# Out:
# Image (3, 198, 179)

# %%
learn = load_learner(PATH)

# %%
preds = learn.predict(img)

# %%
preds[0]
# Out:
# Category cats

# %% [markdown]
# # Test bunch

# %%
tfms = get_transforms(do_flip=False)
learn = load_learner(PATH, test=ImageItemList.from_folder(PATH/'test'))

# %%
preds,y = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds[:5,]
# Out:
# tensor([[5.8181e-03, 9.9418e-01],
#         [9.9980e-01, 1.9831e-04],
#         [1.3735e-03, 9.9863e-01],
#         [1.6000e-02, 9.8400e-01],
#         [9.9817e-01, 1.8323e-03]])
